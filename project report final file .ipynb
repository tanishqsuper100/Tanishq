# %%
#lets import basic  file 
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
#for vizualizing 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel("/Users/isha/Library/Containers/com.microsoft.Excel/Data/Downloads/Input File - Oct 21 Term.xlsx")

# %%
df.head(20)
# Out:
#                                            Unnamed: 0  Campus    Intake Year  \
# 0   UNINETTUNO-2020_Oct-MBA-Maritime and Shipping ...  Berlin  2021_Oct   Y1
# 1                                                 NaN  Berlin  2021_Oct   Y1
# 2                                                 NaN  Berlin  2021_Feb   Y1
# 3                                                 NaN  Berlin  2021_Feb   Y1
# 4                                                 NaN  Berlin  2021_Feb   Y1
# 5                                                 NaN  Berlin  2020_Oct   Y2
# 6                                                 NaN  Berlin  2020_Oct   Y2
# 7                                                 NaN  Berlin  2020_May   Y2
# 8                                                 NaN  Berlin  2020_May   Y2
# 9                                                 NaN  Berlin  2020_Feb   Y2
# 10                                                NaN  Berlin  2020_Feb   Y2
# ...

# %%
#so lets create a plot seeing how many student have opt for which degree most under hwich programe
sns.catplot("Degree",data = df,kind= "count")
# Out:
# /Users/isha/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("Degree",data = df,hue='Programme',kind= "count",aspect=2) #aspect diveide the data
# Out:
# /Users/isha/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("Degree",data = df,hue='Lecturer',kind= "count",alpha=1,aspect=2.5)
# Out:
# /Users/isha/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = df.plot('Lecturer','Teaching_Hours',figsize=(20,5),marker='o',linestyle='-',color='purple')

# %%
df
# Out:
#                                             Unnamed: 0  Campus    Intake Year  \
# 0    UNINETTUNO-2020_Oct-MBA-Maritime and Shipping ...  Berlin  2021_Oct   Y1
# 1                                                  NaN  Berlin  2021_Oct   Y1
# 2                                                  NaN  Berlin  2021_Feb   Y1
# 3                                                  NaN  Berlin  2021_Feb   Y1
# 4                                                  NaN  Berlin  2021_Feb   Y1
# ..                                                 ...     ...       ...  ...
# 147                                                NaN  Berlin  2021_Feb   Y1
# 148                                                NaN  Berlin  2021_May   Y1
# 149                                                NaN  Berlin  2021_May   Y1
# 150                                                NaN  Berlin  2021_May   Y1
# 151                                                NaN  Berlin  2021_May   Y1
#
# ...

# %%
sns.catplot('Intake',data=df,
                kind='count', aspect=2)
# Out:
# /Users/isha/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
